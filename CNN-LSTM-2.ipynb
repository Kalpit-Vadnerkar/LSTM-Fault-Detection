# %%
import torch
import torch.nn as nn
from torch.optim import Adam, SGD
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
import csv
import os

main_directory = '/home/kvadner/Fault Detection/LSTM-Fault-Detection'
data_folder = 'data'  # Adjust if your data folder has a different path
model_name = 'CNN-Label-LSTM-Huber-Batch120'
model_folder = os.path.join(main_directory, 'model', model_name)

# Set device for model training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# LSTM Model
class LSTMModel(nn.Module):
    def __init__(self, num_features, num_classes, hidden_size, num_layers):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size=num_features, hidden_size=hidden_size, 
                            num_layers=num_layers, batch_first=True)
        self.label_fc = nn.Linear(num_classes, hidden_size)
        self.output_fc = nn.Linear(hidden_size, num_features)
    
    def forward(self, x, labels):
        lstm_out, _ = self.lstm(x)
        label_out = self.label_fc(labels)
        label_out = label_out.unsqueeze(1).repeat(1, lstm_out.size(1), 1)
        combined = lstm_out + label_out
        out = self.output_fc(combined)
        return out


# CNN-LSTM Model
class CNNLSTMModel(nn.Module):
    def __init__(self, num_features, num_classes, hidden_size, num_layers):
        super(CNNLSTMModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=num_features, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.relu = nn.ReLU()
        # Adjusting the input size of LSTM to include label information
        self.lstm = nn.LSTM(input_size=64 + num_classes, hidden_size=hidden_size, 
                            num_layers=num_layers, batch_first=True)
        self.label_fc = nn.Linear(num_classes, num_classes)  # Embedding the labels
        self.output_fc = nn.Linear(hidden_size, num_features)
    
    def forward(self, x, labels):
        # Convolutional layers
        x = x.permute(0, 2, 1)
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = x.permute(0, 2, 1)
        
        # Prepare labels
        label_out = self.label_fc(labels)
        # Repeat label embeddings to match sequence length and concatenate with features
        label_out = label_out.unsqueeze(1).repeat(1, x.size(1), 1)
        x = torch.cat((x, label_out), 2)  # Concatenate features with label embeddings
        
        # LSTM layer
        lstm_out, _ = self.lstm(x)
        
        # Output layer
        out = self.output_fc(lstm_out)
        
        return out

# %%
class Seq2SeqLSTM(nn.Module):
    def __init__(self, num_features, hidden_size, n_steps_in, n_steps_out):
        super(Seq2SeqLSTM, self).__init__()

        self.n_steps_out = n_steps_out
        # Encoder LSTM
        self.encoder_lstm = nn.LSTM(input_size=num_features, 
                                    hidden_size=hidden_size, 
                                    batch_first=True)
        # Repeat vector
        self.repeat = lambda x: x.repeat(1, n_steps_out, 1)
        # Decoder LSTM
        self.decoder_lstm = nn.LSTM(input_size=hidden_size, 
                                    hidden_size=hidden_size, 
                                    batch_first=True, 
                                    return_sequences=True)
        # TimeDistributed Dense
        self.time_distributed = nn.Linear(hidden_size, num_features)

    def forward(self, x):
        # Encoding
        encoded, _ = self.encoder_lstm(x)
        # Repeat vector
        repeated = self.repeat(encoded[:, -1, :])
        # Decoding
        decoded, _ = self.decoder_lstm(repeated)
        # TimeDistributed output
        out = self.time_distributed(decoded)

        return out

# %%
class SequentialLSTM(nn.Module):
    def __init__(self, num_features, hidden_size, n_steps_in, n_steps_out):
        super(SequentialLSTM, self).__init__()
        
        # First LSTM layer, returning sequences
        self.lstm1 = nn.LSTM(input_size=num_features, hidden_size=hidden_size, 
                             batch_first=True, return_sequences=True)

        # Second LSTM layer, not returning sequences
        self.lstm2 = nn.LSTM(input_size=hidden_size, hidden_size=hidden_size, 
                             batch_first=True)

        # Dense layer
        self.dense = nn.Linear(hidden_size, n_steps_out)

    def forward(self, x):
        # First LSTM
        x, _ = self.lstm1(x)

        # Second LSTM
        x, _ = self.lstm2(x)

        # Only use the last output for the Dense layer
        x = x[:, -1, :]

        # Dense layer for output
        out = self.dense(x)
        return out

# %%
# Load data
X_data = np.load(os.path.join(main_directory, data_folder, 'X_data.npy'))
maneuver_labels = np.load(os.path.join(main_directory, data_folder, 'maneuver_labels.npy'))
Y_data = np.load(os.path.join(main_directory, data_folder, 'Y_data.npy'))

# Convert to PyTorch tensors
X_tensor = torch.tensor(X_data, dtype=torch.float32)
maneuver_labels_tensor = torch.tensor(maneuver_labels, dtype=torch.float32)
Y_tensor = torch.tensor(Y_data, dtype=torch.float32)

# %%
# Split data into training and test sets
X_train, X_test, labels_train, labels_test, Y_train, Y_test = train_test_split(
    X_tensor, maneuver_labels_tensor, Y_tensor, test_size=0.2, random_state=42)

# Create DataLoader for training and test sets
train_dataset = TensorDataset(X_train, labels_train, Y_train)
test_dataset = TensorDataset(X_test, labels_test, Y_test)

#train_loader = DataLoader(train_dataset, batch_size=120, shuffle=True)
#test_loader = DataLoader(test_dataset, batch_size=120, shuffle=False)

larger_batch_size = 120

train_loader = DataLoader(train_dataset, batch_size=larger_batch_size, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=larger_batch_size, shuffle=False, num_workers=4, pin_memory=True)

# %%
def train_model(model, train_loader, test_loader, epochs, learning_rate):
    #criterion = nn.MSELoss()
    criterion = nn.SmoothL1Loss()
    optimizer = Adam(model.parameters(), lr=learning_rate)
    #optimizer = SGD(model.parameters(), lr=learning_rate, momentum=0.9)  # Using SGD with momentum
    scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5)

    train_losses, test_losses = [], []
    rmse_values = []

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0

        for X_batch, labels_batch, Y_batch in train_loader:
            X_batch = X_batch.permute(0, 2, 1)
            Y_batch = Y_batch.permute(0, 2, 1)
            
            X_batch, labels_batch, Y_batch = X_batch.to(device), labels_batch.to(device), Y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch, labels_batch)
            loss = criterion(outputs, Y_batch)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
        
        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        model.eval()
        total_test_loss = 0
        
        with torch.no_grad():
            for X, labels, Y in test_loader:
                X = X.permute(0, 2, 1)
                Y = Y.permute(0, 2, 1)
                X, labels, Y = X.to(device), labels.to(device), Y.to(device)
                test_outputs = model(X, labels)
                test_loss = criterion(test_outputs, Y)
                total_test_loss += test_loss.item()

        avg_test_loss = total_test_loss / len(test_loader)
        test_losses.append(avg_test_loss)

        # Calculating RMSE
        rmse = np.sqrt(avg_test_loss)
        rmse_values.append(rmse)

        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {avg_train_loss:.4f}, Test Loss: {avg_test_loss:.4f}, RMSE: {rmse:.4f}')
        scheduler.step(avg_test_loss)

    return model, train_losses, test_losses, rmse_values

# %%
# Training the CNN-LSTM model and obtaining metrics
cnn_lstm_model = CNNLSTMModel(num_features=8, num_classes=7, hidden_size=50, num_layers=2)

# Check for multiple GPUs
if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs!")
    cnn_lstm_model = nn.DataParallel(cnn_lstm_model)

cnn_lstm_model.to(device)

# Training the model (as before)
trained_cnn_lstm_model, cnn_lstm_train_losses, cnn_lstm_test_losses, cnn_lstm_rmse = train_model(
    cnn_lstm_model, train_loader, test_loader, epochs=100, learning_rate=0.001)

#trained_cnn_lstm_model, cnn_lstm_train_losses, cnn_lstm_test_losses, cnn_lstm_rmse = train_model(
#    cnn_lstm_model, train_loader, test_loader, epochs=100, learning_rate=0.001)
# Out:
# Using 2 GPUs!
# Epoch 1/100, Train Loss: 0.0235, Test Loss: 0.0162, RMSE: 0.1273
# Epoch 2/100, Train Loss: 0.0154, Test Loss: 0.0152, RMSE: 0.1233
# Epoch 3/100, Train Loss: 0.0143, Test Loss: 0.0137, RMSE: 0.1173
# Epoch 4/100, Train Loss: 0.0137, Test Loss: 0.0135, RMSE: 0.1160
# Epoch 5/100, Train Loss: 0.0133, Test Loss: 0.0133, RMSE: 0.1152
# Epoch 6/100, Train Loss: 0.0130, Test Loss: 0.0131, RMSE: 0.1145
# Epoch 7/100, Train Loss: 0.0128, Test Loss: 0.0128, RMSE: 0.1132
# Epoch 8/100, Train Loss: 0.0126, Test Loss: 0.0126, RMSE: 0.1124
# Epoch 9/100, Train Loss: 0.0125, Test Loss: 0.0125, RMSE: 0.1117
# Epoch 10/100, Train Loss: 0.0124, Test Loss: 0.0123, RMSE: 0.1110
# Epoch 11/100, Train Loss: 0.0123, Test Loss: 0.0124, RMSE: 0.1114
# Epoch 12/100, Train Loss: 0.0122, Test Loss: 0.0121, RMSE: 0.1099
# Epoch 13/100, Train Loss: 0.0121, Test Loss: 0.0120, RMSE: 0.1097
# Epoch 14/100, Train Loss: 0.0120, Test Loss: 0.0119, RMSE: 0.1089
# Epoch 15/100, Train Loss: 0.0120, Test Loss: 0.0117, RMSE: 0.1084
# Epoch 16/100, Train Loss: 0.0119, Test Loss: 0.0121, RMSE: 0.1099
# Epoch 17/100, Train Loss: 0.0118, Test Loss: 0.0121, RMSE: 0.1099
# Epoch 18/100, Train Loss: 0.0118, Test Loss: 0.0117, RMSE: 0.1080
# Epoch 19/100, Train Loss: 0.0117, Test Loss: 0.0117, RMSE: 0.1084
# Epoch 20/100, Train Loss: 0.0117, Test Loss: 0.0117, RMSE: 0.1081
# Epoch 21/100, Train Loss: 0.0116, Test Loss: 0.0114, RMSE: 0.1070
# Epoch 22/100, Train Loss: 0.0116, Test Loss: 0.0117, RMSE: 0.1080
# Epoch 23/100, Train Loss: 0.0116, Test Loss: 0.0116, RMSE: 0.1078
# Epoch 24/100, Train Loss: 0.0115, Test Loss: 0.0114, RMSE: 0.1068
# Epoch 25/100, Train Loss: 0.0115, Test Loss: 0.0116, RMSE: 0.1078
# Epoch 26/100, Train Loss: 0.0115, Test Loss: 0.0116, RMSE: 0.1078
# Epoch 27/100, Train Loss: 0.0115, Test Loss: 0.0114, RMSE: 0.1067
# Epoch 28/100, Train Loss: 0.0115, Test Loss: 0.0117, RMSE: 0.1082
# Epoch 29/100, Train Loss: 0.0114, Test Loss: 0.0114, RMSE: 0.1068
# Epoch 30/100, Train Loss: 0.0114, Test Loss: 0.0112, RMSE: 0.1058
# Epoch 31/100, Train Loss: 0.0114, Test Loss: 0.0116, RMSE: 0.1076
# Epoch 32/100, Train Loss: 0.0113, Test Loss: 0.0116, RMSE: 0.1076
# Epoch 33/100, Train Loss: 0.0113, Test Loss: 0.0116, RMSE: 0.1075
# Epoch 34/100, Train Loss: 0.0113, Test Loss: 0.0112, RMSE: 0.1057
# Epoch 35/100, Train Loss: 0.0113, Test Loss: 0.0115, RMSE: 0.1071
# Epoch 36/100, Train Loss: 0.0113, Test Loss: 0.0114, RMSE: 0.1067
# Epoch 37/100, Train Loss: 0.0113, Test Loss: 0.0117, RMSE: 0.1080
# Epoch 38/100, Train Loss: 0.0112, Test Loss: 0.0112, RMSE: 0.1061
# Epoch 39/100, Train Loss: 0.0112, Test Loss: 0.0112, RMSE: 0.1059
# Epoch 40/100, Train Loss: 0.0112, Test Loss: 0.0114, RMSE: 0.1067
# Epoch 41/100, Train Loss: 0.0106, Test Loss: 0.0107, RMSE: 0.1034
# Epoch 42/100, Train Loss: 0.0106, Test Loss: 0.0106, RMSE: 0.1032
# Epoch 43/100, Train Loss: 0.0105, Test Loss: 0.0106, RMSE: 0.1028
# Epoch 44/100, Train Loss: 0.0105, Test Loss: 0.0107, RMSE: 0.1034
# Epoch 45/100, Train Loss: 0.0105, Test Loss: 0.0105, RMSE: 0.1025
# Epoch 46/100, Train Loss: 0.0105, Test Loss: 0.0105, RMSE: 0.1026
# Epoch 47/100, Train Loss: 0.0105, Test Loss: 0.0106, RMSE: 0.1028
# Epoch 48/100, Train Loss: 0.0105, Test Loss: 0.0107, RMSE: 0.1032
# Epoch 49/100, Train Loss: 0.0105, Test Loss: 0.0105, RMSE: 0.1024
# Epoch 50/100, Train Loss: 0.0105, Test Loss: 0.0105, RMSE: 0.1025
# Epoch 51/100, Train Loss: 0.0104, Test Loss: 0.0105, RMSE: 0.1027
# Epoch 52/100, Train Loss: 0.0104, Test Loss: 0.0105, RMSE: 0.1026
# Epoch 53/100, Train Loss: 0.0104, Test Loss: 0.0107, RMSE: 0.1036
# Epoch 54/100, Train Loss: 0.0104, Test Loss: 0.0105, RMSE: 0.1026
# Epoch 55/100, Train Loss: 0.0104, Test Loss: 0.0104, RMSE: 0.1020
# Epoch 56/100, Train Loss: 0.0104, Test Loss: 0.0105, RMSE: 0.1023
# Epoch 57/100, Train Loss: 0.0104, Test Loss: 0.0105, RMSE: 0.1023
# Epoch 58/100, Train Loss: 0.0104, Test Loss: 0.0104, RMSE: 0.1021
# Epoch 59/100, Train Loss: 0.0104, Test Loss: 0.0104, RMSE: 0.1021
# Epoch 60/100, Train Loss: 0.0104, Test Loss: 0.0105, RMSE: 0.1027
# Epoch 61/100, Train Loss: 0.0104, Test Loss: 0.0105, RMSE: 0.1026
# Epoch 62/100, Train Loss: 0.0100, Test Loss: 0.0101, RMSE: 0.1006
# Epoch 63/100, Train Loss: 0.0100, Test Loss: 0.0102, RMSE: 0.1008
# Epoch 64/100, Train Loss: 0.0100, Test Loss: 0.0101, RMSE: 0.1004
# Epoch 65/100, Train Loss: 0.0100, Test Loss: 0.0101, RMSE: 0.1004
# Epoch 66/100, Train Loss: 0.0100, Test Loss: 0.0101, RMSE: 0.1004
# Epoch 67/100, Train Loss: 0.0100, Test Loss: 0.0101, RMSE: 0.1003
# Epoch 68/100, Train Loss: 0.0100, Test Loss: 0.0102, RMSE: 0.1008
# Epoch 69/100, Train Loss: 0.0100, Test Loss: 0.0101, RMSE: 0.1005
# Epoch 70/100, Train Loss: 0.0100, Test Loss: 0.0100, RMSE: 0.1002
# Epoch 71/100, Train Loss: 0.0100, Test Loss: 0.0101, RMSE: 0.1004
# Epoch 72/100, Train Loss: 0.0100, Test Loss: 0.0101, RMSE: 0.1003
# Epoch 73/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1001
# Epoch 74/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1001
# Epoch 75/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1001
# Epoch 76/100, Train Loss: 0.0099, Test Loss: 0.0101, RMSE: 0.1003
# Epoch 77/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1001
# Epoch 78/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1000
# Epoch 79/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.0998
# Epoch 80/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1001
# Epoch 81/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1001
# Epoch 82/100, Train Loss: 0.0099, Test Loss: 0.0101, RMSE: 0.1003
# Epoch 83/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1001
# Epoch 84/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.0999
# Epoch 85/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.0998
# Epoch 86/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.0999
# Epoch 87/100, Train Loss: 0.0099, Test Loss: 0.0099, RMSE: 0.0997
# Epoch 88/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.0999
# Epoch 89/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.1000
# Epoch 90/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.0998
# Epoch 91/100, Train Loss: 0.0099, Test Loss: 0.0100, RMSE: 0.0998
# Epoch 92/100, Train Loss: 0.0099, Test Loss: 0.0099, RMSE: 0.0996
# Epoch 93/100, Train Loss: 0.0099, Test Loss: 0.0099, RMSE: 0.0997
# Epoch 94/100, Train Loss: 0.0098, Test Loss: 0.0099, RMSE: 0.0996
# Epoch 95/100, Train Loss: 0.0098, Test Loss: 0.0099, RMSE: 0.0996
# Epoch 96/100, Train Loss: 0.0098, Test Loss: 0.0100, RMSE: 0.0998
# Epoch 97/100, Train Loss: 0.0098, Test Loss: 0.0100, RMSE: 0.1001
# Epoch 98/100, Train Loss: 0.0098, Test Loss: 0.0099, RMSE: 0.0997
# Epoch 99/100, Train Loss: 0.0099, Test Loss: 0.0099, RMSE: 0.0994
# Epoch 100/100, Train Loss: 0.0098, Test Loss: 0.0099, RMSE: 0.0993

# %%
# Save the trained model
torch.save(trained_cnn_lstm_model.state_dict(), os.path.join(main_directory, model_folder, 'cnn_lstm_model_100.pth'))

# %%
import matplotlib.pyplot as plt

# Plotting and saving Loss graph
plt.figure()
plt.plot(cnn_lstm_train_losses, label='Train Loss')
plt.plot(cnn_lstm_test_losses, label='Test Loss')
plt.title('CNN-LSTM Model Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.savefig(os.path.join(main_directory, model_folder, 'cnn_lstm_model_MSE.png'))
plt.show()

plt.figure()
plt.plot(cnn_lstm_rmse, label='Test RMSE')
plt.title('CNN-LSTM Model Loss')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()
plt.savefig(os.path.join(main_directory, model_folder, 'cnn_lstm_model_RMSE.png'))
plt.show()

# %%
# Path for the CSV file
csv_file_path = os.path.join(main_directory, model_folder, 'cnn_lstm_model_results.csv')

# Writing metrics to CSV
with open(csv_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Epoch', 'Train Loss', 'Test Loss', 'RMSE'])
    for epoch in range(len(cnn_lstm_train_losses)):
        writer.writerow([epoch + 1, cnn_lstm_train_losses[epoch], cnn_lstm_test_losses[epoch], cnn_lstm_rmse[epoch]])

# %%
import pickle

def loadScaler(variable):
    filename = 'scaler_' + str(variable) + '.pkl'
    with open(os.path.join(main_directory, scaler_folder, filename), 'rb') as file:
        return pickle.load(file)

scaler_folder = 'Scalers'
features = ['theta', 'v', 'r', 'ay', 'force', 'u','xu', 'xy']
# load scalers 
scalers = {variable: loadScaler(variable) for variable in features}
# load model
#model = LSTMModel(num_features=8, num_classes=7, hidden_size=100, num_layers=2).to(device)
#model.load_state_dict(torch.load(os.path.join(main_directory, model_folder, 'stacked_lstm_model_200.pth')))

#model = LSTMModel(num_features=8, num_classes=7, hidden_size=100, num_layers=2).to(device)
#model.load_state_dict(torch.load(os.path.join(main_directory, model_folder, 'lstm_model.pth')))

#model = CNNLSTMModel(num_features=8, num_classes=7, hidden_size=100, num_layers=2).to(device)
#model.load_state_dict(torch.load(os.path.join(main_directory, model_folder, 'cnn_lstm_model_200.pth')))

#model = CNNLSTMModel(num_features=8, num_classes=7, hidden_size=50, num_layers=2).to(device)
#model.load_state_dict(torch.load(os.path.join(main_directory, model_folder, 'cnn_lstm_model_100_Epochs.pth')))

model = CNNLSTMModel(num_features=8, num_classes=7, hidden_size=50, num_layers=2).to(device)
model = nn.DataParallel(model)
model.load_state_dict(torch.load(os.path.join(main_directory, model_folder, 'cnn_lstm_model_100.pth')))

#print(X_data[0])
#print(Y_data[0])
# Out:
# <All keys matched successfully>

# %%
import matplotlib.pyplot as plt

# Select examples based on given indices
indices = [i for i in range(4000, 5000, 25)]
selected_X = X_tensor[indices]
selected_Y = Y_tensor[indices]
selected_labels = maneuver_labels_tensor[indices]

selected_X = selected_X.permute(0, 2, 1)
selected_Y = selected_Y.permute(0, 2, 1)

#model = model.cpu()
#selected_X = selected_X.cpu()
#selected_labels = selected_labels.cpu()
#selected_Y = selected_Y.cpu()

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)  # Move the model to the specified device

# Also move the input data to the same device
selected_X = selected_X.to(device)
selected_labels = selected_labels.to(device)
selected_Y = selected_Y.to(device)

# Make predictions
with torch.no_grad():
    model.eval()
    predicted_Y = model(selected_X, selected_labels)
    
# Move the predictions to CPU for processing with NumPy
predicted_Y = predicted_Y.cpu()
selected_Y = selected_Y.cpu()


# Inverse scaling
inverse_scaled_predicted = []
inverse_scaled_true = []
for i, example in enumerate(predicted_Y):
    inverse_scaled_example = []
    for j, feature in enumerate(features):
        inverse_scaled_example.append(scalers[feature].inverse_transform(example[:, j].numpy().reshape(-1, 1)))
    inverse_scaled_predicted.append(np.hstack(inverse_scaled_example))
    inverse_scaled_true.append(np.hstack([scalers[feature].inverse_transform(selected_Y[i][:, j].numpy().reshape(-1, 1)) for j, feature in enumerate(features)]))

# Plotting
# Concatenate all sequences for each feature
concatenated_true = np.concatenate([inverse_scaled_true[i] for i in range(len(inverse_scaled_true))], axis=0)
concatenated_pred = np.concatenate([inverse_scaled_predicted[i] for i in range(len(inverse_scaled_predicted))], axis=0)

# Plotting
plt.figure(figsize=(12, 15))
for j in range(len(features)):
    plt.subplot(len(features), 1, j + 1)
    plt.plot(concatenated_true[:, j], label=f"True {features[j]}")
    plt.plot(concatenated_pred[:, j], label=f"Predicted {features[j]}")
    plt.legend()
    plt.title(f"Feature: {features[j]} - True vs Predicted")
plt.tight_layout()
plt.savefig(os.path.join(main_directory, model_folder, 'Prediction.png'))
plt.show()
